# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Amazon Sale Report - Amazon Sale Report.csv')

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
rows,columns = df.shape

# %%
rows,columns
# Out:
# (128976, 21)

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Category               object
# Size                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# B2B                      bool
# fulfilled-by           object
# New                   float64
# PendingS              float64
# dtype: object

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code  New  \
# count  128976.000000  128976.000000  121176.000000     128941.000000  0.0
# mean    64486.130427       0.904401     648.562176     463945.677744  NaN
# std     37232.897832       0.313368     281.185041     191458.488954  NaN
# min         0.000000       0.000000       0.000000     110001.000000  NaN
# 25%     32242.750000       1.000000     449.000000     382421.000000  NaN
# 50%     64486.500000       1.000000     605.000000     500033.000000  NaN
# 75%     96730.250000       1.000000     788.000000     600024.000000  NaN
# max    128974.000000      15.000000    5584.000000     989898.000000  NaN
#
#        PendingS
# count       0.0
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
df.isnull()
# Out:
#         index  Order ID   Date  Status  Fulfilment  Sales Channel  \
# 0       False     False  False   False       False          False
# 1       False     False  False   False       False          False
# 2       False     False  False   False       False          False
# 3       False     False  False   False       False          False
# 4       False     False  False   False       False          False
# ...       ...       ...    ...     ...         ...            ...
# 128971  False     False  False   False       False          False
# 128972  False     False  False   False       False          False
# 128973  False     False  False   False       False          False
# 128974  False     False  False   False       False          False
# 128975  False     False  False   False       False          False
#
#         ship-service-level  Category   Size  Courier Status  ...  currency  \
# 0                    False     False  False           False  ...     False
# ...

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
df.isnull().sum()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency                7800
# Amount                  7800
# ship-city                 35
# ship-state                35
# ship-postal-code          35
# ship-country              35
# B2B                        0
# fulfilled-by           89713
# New                   128976
# PendingS              128976
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 363405

# %% [markdown]
# ##Filling Null Values

# %%
df2 = df.fillna(value = 0)
df2
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df2.isnull().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# fulfilled-by          0
# New                   0
# PendingS              0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# index                   0.000000
# Order ID                0.000000
# Date                    0.000000
# Status                  0.000000
# Fulfilment              0.000000
# Sales Channel           0.000000
# ship-service-level      0.000000
# Category                0.000000
# Size                    0.000000
# Courier Status          0.000000
# Qty                     0.000000
# currency                6.047637
# Amount                  6.047637
# ship-city               0.027137
# ship-state              0.027137
# ship-postal-code        0.027137
# ship-country            0.027137
# B2B                     0.000000
# fulfilled-by           69.557902
# New                   100.000000
# PendingS              100.000000
# dtype: float64

# %%
df.drop('New',axis = 1)
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.drop('PendingS',axis = 1)
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# index                   0.000000
# Order ID                0.000000
# Date                    0.000000
# Status                  0.000000
# Fulfilment              0.000000
# Sales Channel           0.000000
# ship-service-level      0.000000
# Category                0.000000
# Size                    0.000000
# Courier Status          0.000000
# Qty                     0.000000
# currency                6.047637
# Amount                  6.047637
# ship-city               0.027137
# ship-state              0.027137
# ship-postal-code        0.027137
# ship-country            0.027137
# B2B                     0.000000
# fulfilled-by           69.557902
# New                   100.000000
# PendingS              100.000000
# dtype: float64

# %%
df.drop(['New','PendingS'],axis = 1,inplace = True)

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Category                  0
# Size                      0
# Courier Status            0
# Qty                       0
# currency               7800
# Amount                 7800
# ship-city                35
# ship-state               35
# ship-postal-code         35
# ship-country             35
# B2B                       0
# fulfilled-by          89713
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# index                  0.000000
# Order ID               0.000000
# Date                   0.000000
# Status                 0.000000
# Fulfilment             0.000000
# Sales Channel          0.000000
# ship-service-level     0.000000
# Category               0.000000
# Size                   0.000000
# Courier Status         0.000000
# Qty                    0.000000
# currency               6.047637
# Amount                 6.047637
# ship-city              0.027137
# ship-state             0.027137
# ship-postal-code       0.027137
# ship-country           0.027137
# B2B                    0.000000
# fulfilled-by          69.557902
# dtype: float64

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
new_df = df.fillna(0)

# %%
new_df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
new_df = df.fillna({'currency': 'Not mention' ,
                    'Amount': 0 , 'ship-country': 'Not mention' ,
                    'ship-postal-code': 0, 'fulfilled-by': 'Not mention'})

# %%
new_df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Category                  0
# Size                      0
# Courier Status            0
# Qty                       0
# currency               7800
# Amount                 7800
# ship-city                35
# ship-state               35
# ship-postal-code         35
# ship-country             35
# B2B                       0
# fulfilled-by          89713
# dtype: int64

# %%
df.ffill(inplace=True)

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.isnull().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# fulfilled-by          0
# dtype: int64

# %%
df.shape
# Out:
# (128976, 19)

# %% [markdown]
# # Order Prioirity

# %%
df['Category'].value_counts()
# Out:
# Category
# T-shirt     50292
# Shirt       49877
# Blazzer     15500
# Trousers    10616
# Perfume      1157
# Wallet        926
# Socks         440
# Shoes         165
# Watch           3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))  
df7 = sns.countplot(x='Category', data=df)
for bars in df7.containers:
    df7.bar_label(bars)
plt.show()

# %%
size_distribution = df['Size'].value_counts()

# Plotting the bar chart
plt.subplot(1, 1, 1)
ax = size_distribution.plot(kind='bar', color='lightgreen')

# Adding title and labels
plt.title('Size Distribution')
plt.xlabel('Size')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Adding labels to each bar
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.show()

# %%
quantity_distribution = df.groupby('Category')['Qty'].sum().sort_values(ascending=False)
plt.subplot(1, 1, 1)
ax = quantity_distribution.plot(kind='bar', color='salmon')
plt.title('Total Quantity Sold by Category')
plt.xlabel('Category')
plt.ylabel('Total Quantity')
plt.xticks(rotation=45)
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.show()

# %% [markdown]
# # Summary:
# Product Distribution: The most popular products are T-shirts and Shirts, with over 49,000 units sold each.
#
#
# Size Distribution: The most common sizes sold are M and L, followed closely by XL.
# Total Quantity Sold: T-shirts and Shirts again lead in total quantities sold, indicating strong demand for these items.

# %% [markdown]
# # ship-service-level

# %%
df['ship-service-level'].value_counts()
# Out:
# ship-service-level
# Expedited    88630
# Standard     40346
# Name: count, dtype: int64

# %% [markdown]
# # Courier Status

# %%
df['Courier Status'].value_counts()
# Out:
# Courier Status
# Shipped       109486
# On the Way      6870
# Unshipped       6680
# Cancelled       5940
# Name: count, dtype: int64

# %%
x = df['Courier Status'].value_counts().index
y = df['Courier Status'].value_counts().values

# %%
plt.figure(figsize=(8,4))
plt.pie(y,labels = x,startangle = 60,autopct = '%0.2f%%')
plt.legend(loc = 2)
plt.show()

# %%
category_courier_counts = df.groupby(['Category', 'Courier Status']).size().unstack()

# Plotting the grouped bar chart
ax = category_courier_counts.plot(kind='bar', stacked=False, figsize=(12, 6))

# Add title and labels
plt.title('Counts of Courier Status by Category')
plt.xlabel('Category')
plt.ylabel('Count')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Add legend
plt.legend(title='Courier Status')



# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Customer Segmentation Based on Buying Behavior, Location, and Key Demographics

# %%
df['ship-country'].value_counts()
# Out:
# ship-country
# IN    128976
# Name: count, dtype: int64

# %%
df['ship-city'].value_counts()
# Out:
# ship-city
# BENGALURU                11210
# HYDERABAD                 8080
# MUMBAI                    6126
# NEW DELHI                 5796
# CHENNAI                   5434
#                          ...
# PERUMBALA                    1
# SONGADH TAPI DISTRICT        1
# oodlabari                    1
# Batika                       1
# Halol                        1
# Name: count, Length: 8948, dtype: int64

# %%
df['ship-city'].unique()
# Out:
# array(['MUMBAI', 'BENGALURU', 'NAVI MUMBAI', ...,
#        'GULABPURA, Distt BHILWARA', 'Prayagraj (ALLAHABAD)', 'Halol'],
#       dtype=object)

# %%
top_names = df['ship-city'].value_counts().nlargest(10)
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x=top_names.index, y=top_names.values, palette="viridis")
for container in bar_plot.containers:
    bar_plot.bar_label(container)
plt.xlabel('City')
plt.ylabel('Count')
plt.title('Top 10 Ship Cities')
plt.xticks(rotation=45)
plt.show()

# %%
city_sales = df.groupby('ship-city')['Amount'].sum()

# Filter the sales data for the top 10 cities
top_city_sales = city_sales[top_names.index]

# Create the bar plot
plt.figure(figsize=(12, 6))
top_city_sales.plot(kind='bar', color='skyblue')  # Bar plot with a sky blue color
plt.title('Total Sales in Top 10 Cities by Number of Orders')
plt.xlabel('City')
plt.ylabel('Total Sales')
plt.xticks(rotation=45, ha='right')  # Rotate x-ticks for better readability
plt.tight_layout()  # Adjust layout to prevent clipping

for index, value in enumerate(top_city_sales):
    plt.text(index, value, f'{value:,.2f}', ha='center', va='bottom')

# Display the plot
plt.show()

# %%
top_names
# Out:
# ship-city
# BENGALURU    11210
# HYDERABAD     8080
# MUMBAI        6126
# NEW DELHI     5796
# CHENNAI       5434
# PUNE          3863
# KOLKATA       2380
# GURUGRAM      1865
# THANE         1701
# LUCKNOW       1464
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Category               object
# Size                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# B2B                      bool
# fulfilled-by           object
# dtype: object

# %%
df['Amount']=df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df['Amount'].sum()
# Out:
# 83652179

# %%
df['ship-postal-code']=df['ship-postal-code'].astype('int')

# %%
df.dtypes
# Out:
# index                  int64
# Order ID              object
# Date                  object
# Status                object
# Fulfilment            object
# Sales Channel         object
# ship-service-level    object
# Category              object
# Size                  object
# Courier Status        object
# Qty                    int64
# currency              object
# Amount                 int32
# ship-city             object
# ship-state            object
# ship-postal-code       int32
# ship-country          object
# B2B                     bool
# fulfilled-by          object
# dtype: object

# %%
df['ship-state'].value_counts()
# Out:
# ship-state
# MAHARASHTRA               22276
# KARNATAKA                 17327
# TAMIL NADU                11496
# TELANGANA                 11333
# UTTAR PRADESH             10651
#                           ...
# Mizoram                       1
# rajsthan                      1
# Punjab/Mohali/Zirakpur        1
# Rajsthan                      1
# orissa                        1
# Name: count, Length: 69, dtype: int64

# %%
top_states = df['ship-state'].value_counts().nlargest(10)

# Create the bar plot
plt.figure(figsize=(12, 6))
ax = top_states.plot(kind='bar', color='skyblue')  # Bar plot with a sky blue color
plt.title('Top 10 States by Number of Orders')
plt.xlabel('State')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45, ha='right')  # Rotate x-ticks for better readability
plt.tight_layout()  # Adjust layout to prevent clipping

# Add labels to each bar
for index, value in enumerate(top_states):
    plt.text(index, value, str(value), ha='center', va='bottom')

# Display the plot
plt.show()

# %%
# Create the pivot table
pivot_table = pd.pivot_table(
    geo_distribution,
    values=['Total Sales', 'Total Quantity', 'Number of Orders'],
    index=['ship-state', 'ship-city'],
    aggfunc='sum'
)

# %%
pivot_table
# Out:
#                                                           Number of Orders  \
# ship-state        ship-city
# ANDAMAN & NICOBAR Andaman and nicobar islands port Blair                 1
#                   BAMBOOFLAT                                            10
#                   FERRARGUNJ                                            10
#                   GARACHARMA                                             1
#                   GREAT NICOBAR                                          3
# ...                                                                    ...
# punjab            phagwara                                               1
# rajasthan         jaipur                                                 3
#                   madanganj-kishangarh  ajmer                            2
#                   sriganganagar                                          1
# rajsthan          Bheem                                                  1
#
# ...

# %%
# Top 10 by Total Sales
top_by_sales = pivot_table.sort_values('Total Sales', ascending=False).head(10)

# Top 10 by Total Quantity
top_by_quantity = pivot_table.sort_values('Total Quantity', ascending=False).head(10)

# Top 10 by Number of Orders
top_by_orders = pivot_table.sort_values('Number of Orders', ascending=False).head(10)

# %%
top_by_sales
# Out:
#                          Number of Orders  Total Quantity  Total Sales
# ship-state    ship-city
# KARNATAKA     BENGALURU             11210           10419      7204754
# TELANGANA     HYDERABAD              8071            7331      5248327
# MAHARASHTRA   MUMBAI                 6126            5650      3875494
# DELHI         NEW DELHI              5786            5243      3830286
# TAMIL NADU    CHENNAI                5434            4950      3294427
# MAHARASHTRA   PUNE                   3863            3539      2470372
# WEST BENGAL   KOLKATA                2380            2164      1498615
# HARYANA       GURUGRAM               1865            1731      1273691
# MAHARASHTRA   THANE                  1701            1539      1065387
# UTTAR PRADESH LUCKNOW                1464            1289      1001186

# %% [markdown]
# # Summary
#
# Cities:
#
# Bengaluru (Karnataka) leads with the highest total sales  followed by Hyderabad (Telangana) and Mumbai (Maharashtra).
# The top cities are generally major metropolitan areas, indicating a concentration of sales in urban centers.
#
# States:
# Maharashtra tops the list with total sales  followed by Karnataka and Telangana.
# There's a significant gap between the top-performing states and those lower on the list, suggesting a concentration of sales in certain regions.
#
# Distribution:
# The bar charts show that while there are clear leaders in both city and state categories, there's also a long tail of smaller contributors to the overall sales.
# This suggests a potential for growth in underperforming regions or cities.
#
# By implementing these recommendations, you can create a more targeted and effective sales strategy, improve customer satisfaction through better product offerings and service, and ultimately enhance overall business performance. Remember to continuously monitor the results of these changes and be prepared to adjust strategies as needed based on new data and market responses.
